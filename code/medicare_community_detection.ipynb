# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %% [markdown]
# ### Support code that makes things run

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))

# %%
session = driver.session(database="neo4j")

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_number_nodes_relationships():
    "print the number of nodes and relationships"
   
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    print("-------------------------")
    print("  Nodes:", number_nodes)
    print("  Relationships:", number_relationships)
    print("-------------------------")

# %% [markdown]
# ### Building code that builds provider nodes

# %%
def my_neo4j_create_provider_node(provider):
    "create a node with label Provider"
    
    query = """
    
    CREATE (:Provider {name: $provider_npi})
    
    """
    
    session.run(query, provider_npi=provider_npi)

# %% [markdown]
# ### Building code for drug nodes

# %%
def my_neo4j_create_drug_node(drug):
    "create a node with label Drug"
    
    query = """
    
    CREATE (:Drug {code: $drug_code})
    
    """
    
    session.run(query, drug_code=drug_code)

# %% [markdown]
# ### Building 1 way relationship between provides and drug prescriptions with a weight

# %%
def my_neo4j_create_relationship_one_way(provider, code ,total_amount_paid):
    "Create a one-way relationship from a provider to a drug they have prescribed with a weight"
    
    query = """
    MATCH (p:Provider {name: $provider}), 
          (d:Drug {code: $code} )
    CREATE (p)-[r:Prescribes {total_amount_paid:$total_amount_paid}]->(d)
    RETURN p, r, d
    """
    
    session.run(query, provider=provider, code=code,total_amount_paid = total_amount_paid)

# %% [markdown]
# ### Clean DB to see if it works

# %%
my_neo4j_wipe_out_database()

# %% [markdown]
# ### Building Nodes

# %%
connection.rollback()

query = """

select provider_npi
from providers
where provider_state = 'AZ'

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    provider_npi = row[0]
    
    my_neo4j_create_provider_node(provider_npi)

# %% [markdown]
# ### Building Drug nodes

# %%
connection.rollback()

query = """

select  
d.drug_code,
d.drug_description
from drugs d
group by 1,2
    


"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    drug_code = row[0]
    
    my_neo4j_create_drug_node(drug_code)

# %% [markdown]
# ### Building drug prescription relationship

# %%
connection.rollback()

query = """

select 
r.provider_npi as from_provider,
r.code as code,
r.total_amount_paid
from services_rendered r
     inner join (
         select provider_npi
            from providers
            where provider_state = 'AZ') k on k.provider_npi = r.provider_npi
where r.drug_indicator = 'Y'

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    provider = row[0]
    code = row[1]
    total_amount_paid = row[2]
    
    my_neo4j_create_relationship_one_way(provider, code, total_amount_paid)

# %% [markdown]
# ### Building procedure nodes

# %%
def my_neo4j_create_procedure_node(procedure):
    "create a node with label Procedure"
    
    query = """
    
    CREATE (:Procedure {code: $procedure})
    
    """
    
    session.run(query, procedure=procedure)

# %%
connection.rollback()

query = """

select 
procedure_code as procedure,
procedure_description as description
from procedures


"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    
    procedure = row[0]
    
    my_neo4j_create_procedure_node(procedure)

# %% [markdown]
# ### Build Procedure Relationship

# %%
def my_neo4j_create_relationship_one_way_procedure(provider, procedure, total_amount_paid):
    "Create a one-way relationship from a provider to a drug they have prescribed with a weight"
    
    query = """
    MATCH (p:Provider {name:$provider}), 
          (d:Procedure {code: $procedure})
    CREATE (p)-[r:Conducted {total_amount_paid:$total_amount_paid}]->(d)
    RETURN p, r, d
    """
    
    session.run(query, provider=provider, procedure=procedure, total_amount_paid = total_amount_paid)

# %%
connection.rollback()

query = """

select 
r.provider_npi as from_provider,
r.code as procedure,
r.total_amount_paid
from services_rendered r
     inner join (
         select provider_npi
            from providers
            where provider_state = 'AZ') k on k.provider_npi = r.provider_npi
where r.drug_indicator = 'N'

"""

cursor.execute(query)

connection.rollback()

rows = cursor.fetchall()

for row in rows:
    provider = row[0]
    procedure = row[1]
    total_amount_paid = row[2]
    
    my_neo4j_create_relationship_one_way_procedure(provider, procedure, total_amount_paid)

# %%
def my_neo4j_create_relationship_one_way_procedure(provider, procedure, total_amount_paid):
    query = """
    MATCH (p:Provider {NPI: $provider}), (pr:Procedure {code: $procedure})
    CREATE (p)-[:RECOMMENDS {amount_paid: $total_amount_paid}]->(pr)
    """
    session.run(query, provider=provider, procedure=procedure, total_amount_paid=total_amount_paid)

# %%
query = """
select 
    r.provider_npi as from_provider,
    r.code as procedure,
    r.total_amount_paid
from services_rendered r
    inner join (
        select provider_npi
        from providers
        where provider_state = 'FL'
    ) k on k.provider_npi = r.provider_npi
where r.drug_indicator = 'N'
order by r.total_amount_paid desc
limit 100
"""

cursor.execute(query)

# Fetch rows
rows = cursor.fetchall()

# Iterate through rows and create relationships in Neo4j
for row in rows:
    provider = row[0]
    procedure = row[1]
    total_amount_paid = row[2]
    
    # Print to check the data before calling the function
    print(f"Creating relationship for Provider: {provider}, Procedure: {procedure}, Total Paid: {total_amount_paid}")
    
    # Create the relationship in Neo4j
    my_neo4j_create_relationship_one_way_procedure(provider, procedure, total_amount_paid)
# Out:
# Creating relationship for Provider: 1699115014, Procedure: 14301, Total Paid: 1967.22
# Creating relationship for Provider: 1417073503, Procedure: 15260, Total Paid: 1805.39
# Creating relationship for Provider: 1699115014, Procedure: 15260, Total Paid: 1767.61
# Creating relationship for Provider: 1699115014, Procedure: 14061, Total Paid: 1762.21
# Creating relationship for Provider: 1740556364, Procedure: 14060, Total Paid: 1541.34
# Creating relationship for Provider: 1164614004, Procedure: 36465, Total Paid: 1337.62
# Creating relationship for Provider: 1619081155, Procedure: 14301, Total Paid: 1186.38
# Creating relationship for Provider: 1467458984, Procedure: 14301, Total Paid: 1169.76
# Creating relationship for Provider: 1902828049, Procedure: 14301, Total Paid: 1161.96
# Creating relationship for Provider: 1538272653, Procedure: 14301, Total Paid: 1158.08
# Creating relationship for Provider: 1073518692, Procedure: 14301, Total Paid: 1153.62
# Creating relationship for Provider: 1871577700, Procedure: 14301, Total Paid: 1151.46
# Creating relationship for Provider: 1528385507, Procedure: 14301, Total Paid: 1137.37
# Creating relationship for Provider: 1538115548, Procedure: 14301, Total Paid: 1110.64
# Creating relationship for Provider: 1619317575, Procedure: 14301, Total Paid: 1109.57
# Creating relationship for Provider: 1932189008, Procedure: 14301, Total Paid: 1109.1
# Creating relationship for Provider: 1649664731, Procedure: 14301, Total Paid: 1108.04
# Creating relationship for Provider: 1700828290, Procedure: 14301, Total Paid: 1107.76
# Creating relationship for Provider: 1477932341, Procedure: 14301, Total Paid: 1107.47
# Creating relationship for Provider: 1770726291, Procedure: 14301, Total Paid: 1105.49
# Creating relationship for Provider: 1164461976, Procedure: 14301, Total Paid: 1105.48
# Creating relationship for Provider: 1437117116, Procedure: 14301, Total Paid: 1102.0
# Creating relationship for Provider: 1568604668, Procedure: 14301, Total Paid: 1101.01
# Creating relationship for Provider: 1790196699, Procedure: 14301, Total Paid: 1100.82
# Creating relationship for Provider: 1396816765, Procedure: 14301, Total Paid: 1097.29
# Creating relationship for Provider: 1043204365, Procedure: 14301, Total Paid: 1093.37
# Creating relationship for Provider: 1457332819, Procedure: 14301, Total Paid: 1092.24
# Creating relationship for Provider: 1982053419, Procedure: 14301, Total Paid: 1090.5
# Creating relationship for Provider: 1437512969, Procedure: 14301, Total Paid: 1089.86
# Creating relationship for Provider: 1104810563, Procedure: 14301, Total Paid: 1089.56
# Creating relationship for Provider: 1073518692, Procedure: 15260, Total Paid: 1083.79
# Creating relationship for Provider: 1619081155, Procedure: 14061, Total Paid: 1080.77
# Creating relationship for Provider: 1083644421, Procedure: 17311, Total Paid: 1077.43
# Creating relationship for Provider: 1982740775, Procedure: 14301, Total Paid: 1071.17
# Creating relationship for Provider: 1003142084, Procedure: 15260, Total Paid: 1062.8
# Creating relationship for Provider: 1508150707, Procedure: 15260, Total Paid: 1062.43
# Creating relationship for Provider: 1437117058, Procedure: 15260, Total Paid: 1060.61
# Creating relationship for Provider: 1033148382, Procedure: 15260, Total Paid: 1060.24
# Creating relationship for Provider: 1922033471, Procedure: 15260, Total Paid: 1059.89
# Creating relationship for Provider: 1679745657, Procedure: 15260, Total Paid: 1057.59
# Creating relationship for Provider: 1053421446, Procedure: 14061, Total Paid: 1056.14
# Creating relationship for Provider: 1659512366, Procedure: 36475, Total Paid: 1055.45
# Creating relationship for Provider: 1396140695, Procedure: 14301, Total Paid: 1054.73
# Creating relationship for Provider: 1720039829, Procedure: Q4194, Total Paid: 1054.68
# Creating relationship for Provider: 1245432970, Procedure: 14301, Total Paid: 1054.45
# Creating relationship for Provider: 1245362763, Procedure: 14061, Total Paid: 1054.28
# Creating relationship for Provider: 1467458984, Procedure: 15260, Total Paid: 1053.7
# Creating relationship for Provider: 1063519254, Procedure: 14061, Total Paid: 1053.51
# Creating relationship for Provider: 1871540377, Procedure: 15260, Total Paid: 1052.86
# Creating relationship for Provider: 1487834693, Procedure: 15260, Total Paid: 1052.26
# Creating relationship for Provider: 1700882545, Procedure: 15260, Total Paid: 1051.5
# Creating relationship for Provider: 1568538783, Procedure: 15260, Total Paid: 1051.39
# Creating relationship for Provider: 1952394199, Procedure: 15260, Total Paid: 1049.69
# Creating relationship for Provider: 1396764460, Procedure: Q4194, Total Paid: 1049.46
# Creating relationship for Provider: 1902828049, Procedure: 15260, Total Paid: 1048.9
# Creating relationship for Provider: 1245362763, Procedure: 15260, Total Paid: 1048.71
# Creating relationship for Provider: 1992956247, Procedure: 14301, Total Paid: 1048.0
# Creating relationship for Provider: 1700882545, Procedure: 14061, Total Paid: 1047.11
# Creating relationship for Provider: 1467458984, Procedure: 14061, Total Paid: 1046.63
# Creating relationship for Provider: 1013962638, Procedure: 15260, Total Paid: 1045.92
# Creating relationship for Provider: 1386862415, Procedure: 15260, Total Paid: 1044.95
# Creating relationship for Provider: 1952369779, Procedure: 15260, Total Paid: 1044.51
# Creating relationship for Provider: 1073502209, Procedure: Q4194, Total Paid: 1043.69
# Creating relationship for Provider: 1144215898, Procedure: Q4194, Total Paid: 1043.01
# Creating relationship for Provider: 1659538809, Procedure: 15260, Total Paid: 1041.66
# Creating relationship for Provider: 1952369779, Procedure: 14061, Total Paid: 1040.46
# Creating relationship for Provider: 1457321028, Procedure: Q4194, Total Paid: 1037.91
# Creating relationship for Provider: 1255376711, Procedure: 14061, Total Paid: 1035.66
# Creating relationship for Provider: 1174942403, Procedure: 14041, Total Paid: 1032.71
# Creating relationship for Provider: 1164614004, Procedure: 36478, Total Paid: 1030.25
# Creating relationship for Provider: 1871577700, Procedure: 15260, Total Paid: 1026.64
# Creating relationship for Provider: 1528385507, Procedure: 15260, Total Paid: 1022.51
# Creating relationship for Provider: 1073518692, Procedure: 15240, Total Paid: 1021.69
# Creating relationship for Provider: 1013962638, Procedure: 14061, Total Paid: 1018.11
# Creating relationship for Provider: 1255323978, Procedure: 15260, Total Paid: 1009.7
# Creating relationship for Provider: 1700828290, Procedure: 15260, Total Paid: 1007.34
# Creating relationship for Provider: 1447256201, Procedure: 15260, Total Paid: 1007.34
# Creating relationship for Provider: 1598765760, Procedure: 15260, Total Paid: 1005.75
# Creating relationship for Provider: 1972708329, Procedure: 15260, Total Paid: 1005.68
# Creating relationship for Provider: 1104814235, Procedure: 15260, Total Paid: 1005.42
# Creating relationship for Provider: 1275710758, Procedure: 15260, Total Paid: 1005.2
# Creating relationship for Provider: 1487619078, Procedure: 15260, Total Paid: 1005.12
# Creating relationship for Provider: 1992956247, Procedure: 15260, Total Paid: 1004.95
# Creating relationship for Provider: 1508092347, Procedure: 15260, Total Paid: 1004.74
# Creating relationship for Provider: 1477932341, Procedure: 15260, Total Paid: 1004.63
# Creating relationship for Provider: 1124069398, Procedure: 15260, Total Paid: 1004.14
# Creating relationship for Provider: 1134160294, Procedure: 15260, Total Paid: 1004.13
# Creating relationship for Provider: 1902828049, Procedure: 14061, Total Paid: 1004.05
# Creating relationship for Provider: 1003812207, Procedure: 15260, Total Paid: 1004.04
# Creating relationship for Provider: 1063590149, Procedure: 15260, Total Paid: 1003.68
# Creating relationship for Provider: 1801214721, Procedure: 15260, Total Paid: 1003.62
# Creating relationship for Provider: 1003083247, Procedure: 15260, Total Paid: 1003.04
# Creating relationship for Provider: 1629104427, Procedure: 14061, Total Paid: 1000.56
# Creating relationship for Provider: 1790196699, Procedure: 15260, Total Paid: 1000.55
# Creating relationship for Provider: 1275710758, Procedure: 14061, Total Paid: 1000.51
# Creating relationship for Provider: 1376772707, Procedure: 14061, Total Paid: 1000.36
# Creating relationship for Provider: 1629104427, Procedure: 15260, Total Paid: 999.72
# Creating relationship for Provider: 1770726291, Procedure: 14061, Total Paid: 999.67
# Creating relationship for Provider: 1548396260, Procedure: 15260, Total Paid: 999.36
# Creating relationship for Provider: 1902811219, Procedure: 15260, Total Paid: 999.3

# %%
query = """
MATCH (p:Service {provider_npi: $provider_npi})-[:PERFORMED]->(d:DrugProcedure)
GROUP BY p.provider_npi, d.procedure
WITH p.provider_npi, d.procedure, COUNT(*) AS count
ORDER BY count DESC
RETURN p.provider_npi, d.procedure, count


"""

# %%
def my_neo4j_shortest_path(from_provider, to_provider):
    """
    Find the shortest path from one provider to another in Arizona, traversing through drugs.
    """
    # Drop any existing graph to avoid conflicts
    query = "CALL gds.graph.drop('ds_graph', false) YIELD graphName"
    session.run(query)

    # Project the graph with the proper direction and weights
    query = """
    CALL gds.graph.project(
        'ds_graph',
        ['Provider', 'Drug'],
        { Prescribes: { type: 'Prescribes', properties: ['total_amount_paid'] } }
    )
    """
    session.run(query)

    # Adjusted query: Path between providers in Arizona through drugs
    query = """
    MATCH (source:Provider {name: $from_provider})-[:Prescribes]->(drug:Drug)<-[:Prescribes]-(target:Provider {name: $to_provider})
    CALL gds.shortestPath.dijkstra.stream(
        'ds_graph',
        { 
          sourceNode: source, 
          targetNode: target, 
          relationshipWeightProperty: 'total_amount_paid'
        }
    )
    YIELD index, sourceNode, targetNode, totalCost, nodeIds, costs
    RETURN
        gds.util.asNode(nodeIds[0]).name AS start_provider,
        [nodeId IN nodeIds[1..-1] WHERE gds.util.asNode(nodeId):Drug | gds.util.asNode(nodeId).code] AS drugs_in_path,
        gds.util.asNode(nodeIds[-1]).name AS end_provider,
        totalCost,
        costs
    """
    # Execute the query
    result = session.run(query, from_provider=from_provider, to_provider=to_provider)
    
    results_found = False
    for r in result:
        results_found = True
        total_cost = float(r['totalCost'])
        print("\n--------------------------------")
        print(f"   Total Cost (Total Amount Paid): {total_cost}")
        print("--------------------------------")
        
        drugs_in_path = r['drugs_in_path']
        print(f"Drugs in Path: {drugs_in_path}")
    
    if not results_found:
        print("No path found. Please verify the data and relationships.")

# %%
my_neo4j_shortest_path('1164683793', '1174506265')
# Out:
# No path found. Please verify the data and relationships.

# %%
def my_neo4j_shortest_path(from_provider, to_provider):
    """
    Given a from_provider and to_provider, run and print the shortest path via procedures.
    """
    
    # Drop any existing graph to avoid conflicts (ensure it's a fresh graph)
    query = "CALL gds.graph.drop('ds_graph', false) YIELD graphName"
    session.run(query)

    # Project the graph with 'Provider' nodes and 'Prescribes' relationships (via procedure)
    query = """
    CALL gds.graph.project(
        'ds_graph', 
        'Provider', 
        'Prescribes', 
        { relationshipProperties: 'total_amount_paid' }
    )
    """
    session.run(query)

    # Query to find the shortest path between two providers (through procedures)
    query = """
    MATCH (source:Provider {name: $from_provider}), 
          (target:Provider {name: $to_provider})
    CALL gds.shortestPath.dijkstra.stream(
        'ds_graph', 
        { 
          sourceNode: source, 
          targetNode: target, 
          relationshipWeightProperty: 'total_amount_paid'
        }
    )
    YIELD index, sourceNode, targetNode, totalCost, nodeIds, costs, path
    RETURN
        gds.util.asNode(sourceNode).name AS from,
        gds.util.asNode(targetNode).name AS to,
        totalCost,
        [nodeId IN nodeIds | gds.util.asNode(nodeId).name] AS providers_in_path,
        costs,
        path
    ORDER BY index
    """
    
    # Ensure you're passing the correct parameters here
    result = session.run(query, from_provider=from_provider, to_provider=to_provider)

    results_found = False
    for r in result:
        results_found = True
        total_cost = float(r['totalCost'])
        print("\n--------------------------------")
        print(f"   Total Cost (Total Amount Paid): {total_cost}")
        print("--------------------------------")
        
        providers_in_path = r['providers_in_path']
        print(f"Providers in Path: {providers_in_path}")
    
    if not results_found:
        print("No path found. Please verify the data and relationships.")

# %%
my_neo4j_shortest_path('1962780841', '1851515381')
# Out:
# No path found. Please verify the data and relationships.

# %%
# Step 1: Run Louvain Community Detection
community_detection_query = """
CALL gds.louvain.write('ds_graph', {
    writeProperty: 'community'
})
"""
session.run(community_detection_query)

find_anomalous_providers_query = """
MATCH (p:Provider)
WHERE p.community IS NOT NULL
WITH p.community AS community, count(p) AS community_size
WHERE community_size < 5  
MATCH (p2:Provider)
WHERE p2.community = community
RETURN p2.name AS provider_name, p2.community AS community, community_size
ORDER BY community_size ASC
LIMIT 500
"""

result = session.run(find_anomalous_providers_query)

# Step 3: Display results
for record in result:
    print(f"Provider Name: {record['provider_name']}, Community: {record['community']}, Community Size: {record['community_size']}")
# Out:
# Provider Name: 1003079773, Community: 0, Community Size: 1
# Provider Name: 1013160563, Community: 1, Community Size: 1
# Provider Name: 1013170695, Community: 2, Community Size: 1
# Provider Name: 1013457662, Community: 3, Community Size: 1
# Provider Name: 1023338241, Community: 4, Community Size: 1
# Provider Name: 1023372950, Community: 5, Community Size: 1
# Provider Name: 1033182381, Community: 6, Community Size: 1
# Provider Name: 1033386669, Community: 7, Community Size: 1
# Provider Name: 1033568761, Community: 8, Community Size: 1
# Provider Name: 1043620065, Community: 9, Community Size: 1
# Provider Name: 1053631457, Community: 10, Community Size: 1
# Provider Name: 1063470623, Community: 11, Community Size: 1
# Provider Name: 1063619484, Community: 12, Community Size: 1
# Provider Name: 1063623148, Community: 13, Community Size: 1
# Provider Name: 1063668531, Community: 14, Community Size: 1
# Provider Name: 1073585402, Community: 15, Community Size: 1
# Provider Name: 1073860920, Community: 16, Community Size: 1
# Provider Name: 1083024921, Community: 17, Community Size: 1
# Provider Name: 1083052872, Community: 18, Community Size: 1
# Provider Name: 1083054571, Community: 19, Community Size: 1
# Provider Name: 1083606305, Community: 20, Community Size: 1
# Provider Name: 1083608699, Community: 21, Community Size: 1
# Provider Name: 1083621148, Community: 22, Community Size: 1
# Provider Name: 1083637359, Community: 23, Community Size: 1
# Provider Name: 1083661474, Community: 24, Community Size: 1
# Provider Name: 1083662662, Community: 25, Community Size: 1
# Provider Name: 1083841225, Community: 26, Community Size: 1
# Provider Name: 1093827362, Community: 27, Community Size: 1
# Provider Name: 1093884843, Community: 28, Community Size: 1
# Provider Name: 1093959744, Community: 29, Community Size: 1
# Provider Name: 1104271816, Community: 30, Community Size: 1
# Provider Name: 1104810720, Community: 31, Community Size: 1
# Provider Name: 1114903358, Community: 32, Community Size: 1
# Provider Name: 1124008255, Community: 33, Community Size: 1
# Provider Name: 1124236054, Community: 34, Community Size: 1
# Provider Name: 1134102254, Community: 35, Community Size: 1
# Provider Name: 1134128564, Community: 36, Community Size: 1
# Provider Name: 1134140999, Community: 37, Community Size: 1
# Provider Name: 1134192859, Community: 38, Community Size: 1
# Provider Name: 1144270059, Community: 39, Community Size: 1
# Provider Name: 1164401675, Community: 40, Community Size: 1
# Provider Name: 1164403010, Community: 41, Community Size: 1
# Provider Name: 1164683793, Community: 42, Community Size: 1
# Provider Name: 1174506265, Community: 43, Community Size: 1
# Provider Name: 1174546444, Community: 44, Community Size: 1
# Provider Name: 1174595920, Community: 45, Community Size: 1
# Provider Name: 1174729966, Community: 46, Community Size: 1
# Provider Name: 1174918387, Community: 47, Community Size: 1
# Provider Name: 1194727008, Community: 48, Community Size: 1
# Provider Name: 1194868356, Community: 49, Community Size: 1
# Provider Name: 1194967521, Community: 50, Community Size: 1
# Provider Name: 1205330727, Community: 51, Community Size: 1
# Provider Name: 1215293782, Community: 52, Community Size: 1
# Provider Name: 1215374186, Community: 53, Community Size: 1
# Provider Name: 1225526460, Community: 54, Community Size: 1
# Provider Name: 1225598675, Community: 55, Community Size: 1
# Provider Name: 1235118340, Community: 56, Community Size: 1
# Provider Name: 1235134412, Community: 57, Community Size: 1
# Provider Name: 1235153818, Community: 58, Community Size: 1
# Provider Name: 1235391889, Community: 59, Community Size: 1
# Provider Name: 1245226042, Community: 60, Community Size: 1
# Provider Name: 1245280031, Community: 61, Community Size: 1
# Provider Name: 1245303718, Community: 62, Community Size: 1
# Provider Name: 1245443522, Community: 63, Community Size: 1
# Provider Name: 1245488444, Community: 64, Community Size: 1
# Provider Name: 1255308003, Community: 65, Community Size: 1
# Provider Name: 1255517041, Community: 66, Community Size: 1
# Provider Name: 1255543971, Community: 67, Community Size: 1
# Provider Name: 1255650073, Community: 68, Community Size: 1
# Provider Name: 1265431274, Community: 69, Community Size: 1
# Provider Name: 1265439335, Community: 70, Community Size: 1
# Provider Name: 1265455539, Community: 71, Community Size: 1
# Provider Name: 1265490429, Community: 72, Community Size: 1
# Provider Name: 1265501779, Community: 73, Community Size: 1
# Provider Name: 1265920730, Community: 74, Community Size: 1
# Provider Name: 1275196784, Community: 75, Community Size: 1
# Provider Name: 1275546533, Community: 76, Community Size: 1
# Provider Name: 1275820151, Community: 77, Community Size: 1
# Provider Name: 1285139063, Community: 78, Community Size: 1
# Provider Name: 1285611582, Community: 79, Community Size: 1
# Provider Name: 1285955039, Community: 80, Community Size: 1
# Provider Name: 1295927788, Community: 81, Community Size: 1
# Provider Name: 1295965119, Community: 82, Community Size: 1
# Provider Name: 1306010467, Community: 83, Community Size: 1
# Provider Name: 1306067640, Community: 84, Community Size: 1
# Provider Name: 1306342811, Community: 85, Community Size: 1
# Provider Name: 1316054398, Community: 86, Community Size: 1
# Provider Name: 1326031055, Community: 87, Community Size: 1
# Provider Name: 1326239120, Community: 88, Community Size: 1
# Provider Name: 1326240946, Community: 89, Community Size: 1
# Provider Name: 1336255793, Community: 90, Community Size: 1
# Provider Name: 1336341650, Community: 91, Community Size: 1
# Provider Name: 1336671312, Community: 92, Community Size: 1
# Provider Name: 1346633161, Community: 93, Community Size: 1
# Provider Name: 1356364624, Community: 94, Community Size: 1
# Provider Name: 1356491997, Community: 95, Community Size: 1
# Provider Name: 1356791461, Community: 96, Community Size: 1
# Provider Name: 1366753865, Community: 97, Community Size: 1
# Provider Name: 1376832196, Community: 98, Community Size: 1
# Provider Name: 1386061257, Community: 99, Community Size: 1
# Provider Name: 1386091163, Community: 100, Community Size: 1
# Provider Name: 1386603652, Community: 101, Community Size: 1
# Provider Name: 1386808368, Community: 102, Community Size: 1
# Provider Name: 1386871523, Community: 103, Community Size: 1
# Provider Name: 1396122727, Community: 104, Community Size: 1
# Provider Name: 1396155867, Community: 105, Community Size: 1
# Provider Name: 1396955076, Community: 106, Community Size: 1
# Provider Name: 1396962767, Community: 107, Community Size: 1
# Provider Name: 1407842826, Community: 108, Community Size: 1
# Provider Name: 1417054198, Community: 109, Community Size: 1
# Provider Name: 1417279068, Community: 110, Community Size: 1
# Provider Name: 1417906280, Community: 111, Community Size: 1
# Provider Name: 1417940123, Community: 112, Community Size: 1
# Provider Name: 1427037530, Community: 113, Community Size: 1
# Provider Name: 1427051184, Community: 114, Community Size: 1
# Provider Name: 1427160548, Community: 115, Community Size: 1
# Provider Name: 1427344415, Community: 116, Community Size: 1
# Provider Name: 1427404102, Community: 117, Community Size: 1
# Provider Name: 1437276276, Community: 118, Community Size: 1
# Provider Name: 1437447745, Community: 119, Community Size: 1
# Provider Name: 1437612470, Community: 120, Community Size: 1
# Provider Name: 1447429097, Community: 121, Community Size: 1
# Provider Name: 1447505755, Community: 122, Community Size: 1
# Provider Name: 1447875372, Community: 123, Community Size: 1
# Provider Name: 1457312027, Community: 124, Community Size: 1
# Provider Name: 1457391732, Community: 125, Community Size: 1
# Provider Name: 1457581019, Community: 126, Community Size: 1
# Provider Name: 1457857336, Community: 127, Community Size: 1
# Provider Name: 1467431668, Community: 128, Community Size: 1
# Provider Name: 1467437152, Community: 129, Community Size: 1
# Provider Name: 1467555813, Community: 130, Community Size: 1
# Provider Name: 1477007136, Community: 131, Community Size: 1
# Provider Name: 1477081149, Community: 132, Community Size: 1
# Provider Name: 1487048583, Community: 133, Community Size: 1
# Provider Name: 1487615407, Community: 134, Community Size: 1
# Provider Name: 1487659454, Community: 135, Community Size: 1
# Provider Name: 1497703797, Community: 136, Community Size: 1
# Provider Name: 1497716625, Community: 137, Community Size: 1
# Provider Name: 1508494592, Community: 138, Community Size: 1
# Provider Name: 1508852302, Community: 139, Community Size: 1
# Provider Name: 1508893975, Community: 140, Community Size: 1
# Provider Name: 1518045517, Community: 141, Community Size: 1
# Provider Name: 1518137306, Community: 142, Community Size: 1
# Provider Name: 1518535095, Community: 143, Community Size: 1
# Provider Name: 1528011368, Community: 144, Community Size: 1
# Provider Name: 1528022779, Community: 145, Community Size: 1
# Provider Name: 1528040383, Community: 146, Community Size: 1
# Provider Name: 1528054855, Community: 147, Community Size: 1
# Provider Name: 1528248747, Community: 148, Community Size: 1
# Provider Name: 1538142625, Community: 149, Community Size: 1
# Provider Name: 1538238373, Community: 150, Community Size: 1
# Provider Name: 1538546957, Community: 151, Community Size: 1
# Provider Name: 1548241235, Community: 152, Community Size: 1
# Provider Name: 1548652878, Community: 153, Community Size: 1
# Provider Name: 1558312991, Community: 154, Community Size: 1
# Provider Name: 1558330365, Community: 155, Community Size: 1
# Provider Name: 1558371179, Community: 156, Community Size: 1
# Provider Name: 1568544088, Community: 157, Community Size: 1
# Provider Name: 1568877397, Community: 158, Community Size: 1
# Provider Name: 1568955300, Community: 159, Community Size: 1
# Provider Name: 1578776027, Community: 160, Community Size: 1
# Provider Name: 1578919403, Community: 161, Community Size: 1
# Provider Name: 1588610422, Community: 162, Community Size: 1
# Provider Name: 1588612964, Community: 163, Community Size: 1
# Provider Name: 1588956361, Community: 164, Community Size: 1
# Provider Name: 1598063679, Community: 165, Community Size: 1
# Provider Name: 1598143570, Community: 166, Community Size: 1
# Provider Name: 1609139138, Community: 167, Community Size: 1
# Provider Name: 1609162049, Community: 168, Community Size: 1
# Provider Name: 1609900299, Community: 169, Community Size: 1
# Provider Name: 1619222429, Community: 170, Community Size: 1
# Provider Name: 1619293891, Community: 171, Community Size: 1
# Provider Name: 1629047345, Community: 172, Community Size: 1
# Provider Name: 1629071907, Community: 173, Community Size: 1
# Provider Name: 1629099072, Community: 174, Community Size: 1
# Provider Name: 1629488424, Community: 175, Community Size: 1
# Provider Name: 1649226705, Community: 176, Community Size: 1
# Provider Name: 1649274671, Community: 177, Community Size: 1
# Provider Name: 1659589638, Community: 178, Community Size: 1
# Provider Name: 1669634200, Community: 179, Community Size: 1
# Provider Name: 1669703286, Community: 180, Community Size: 1
# Provider Name: 1679685614, Community: 181, Community Size: 1
# Provider Name: 1679928519, Community: 182, Community Size: 1
# Provider Name: 1679928832, Community: 183, Community Size: 1
# Provider Name: 1689037152, Community: 184, Community Size: 1
# Provider Name: 1689087348, Community: 185, Community Size: 1
# Provider Name: 1689859514, Community: 186, Community Size: 1
# Provider Name: 1699087809, Community: 187, Community Size: 1
# Provider Name: 1700272978, Community: 188, Community Size: 1
# Provider Name: 1700893864, Community: 189, Community Size: 1
# Provider Name: 1710056221, Community: 190, Community Size: 1
# Provider Name: 1710971320, Community: 191, Community Size: 1
# Provider Name: 1720268188, Community: 192, Community Size: 1
# Provider Name: 1730406596, Community: 193, Community Size: 1
# Provider Name: 1750380762, Community: 194, Community Size: 1
# Provider Name: 1750394227, Community: 195, Community Size: 1
# Provider Name: 1750416608, Community: 196, Community Size: 1
# Provider Name: 1750575643, Community: 197, Community Size: 1
# Provider Name: 1750726253, Community: 198, Community Size: 1
# Provider Name: 1760408785, Community: 199, Community Size: 1
# Provider Name: 1760801070, Community: 200, Community Size: 1
# Provider Name: 1760824338, Community: 201, Community Size: 1
# Provider Name: 1780653030, Community: 202, Community Size: 1
# Provider Name: 1780677492, Community: 203, Community Size: 1
# Provider Name: 1780863092, Community: 204, Community Size: 1
# Provider Name: 1821046772, Community: 205, Community Size: 1
# Provider Name: 1831191741, Community: 206, Community Size: 1
# Provider Name: 1841223583, Community: 207, Community Size: 1
# Provider Name: 1841230976, Community: 208, Community Size: 1
# Provider Name: 1841313020, Community: 209, Community Size: 1
# Provider Name: 1851340467, Community: 210, Community Size: 1
# Provider Name: 1851376305, Community: 211, Community Size: 1
# Provider Name: 1851515381, Community: 212, Community Size: 1
# Provider Name: 1851736763, Community: 213, Community Size: 1
# Provider Name: 1861072654, Community: 214, Community Size: 1
# Provider Name: 1861434094, Community: 215, Community Size: 1
# Provider Name: 1861498297, Community: 216, Community Size: 1
# Provider Name: 1861506230, Community: 217, Community Size: 1
# Provider Name: 1871634725, Community: 218, Community Size: 1
# Provider Name: 1871937417, Community: 219, Community Size: 1
# Provider Name: 1881198588, Community: 220, Community Size: 1
# Provider Name: 1881629376, Community: 221, Community Size: 1
# Provider Name: 1881680080, Community: 222, Community Size: 1
# Provider Name: 1881913846, Community: 223, Community Size: 1
# Provider Name: 1902845738, Community: 224, Community Size: 1
# Provider Name: 1902852320, Community: 225, Community Size: 1
# Provider Name: 1902889546, Community: 226, Community Size: 1
# Provider Name: 1902929318, Community: 227, Community Size: 1
# Provider Name: 1912007683, Community: 228, Community Size: 1
# Provider Name: 1912160482, Community: 229, Community Size: 1
# Provider Name: 1922118298, Community: 230, Community Size: 1
# Provider Name: 1922164714, Community: 231, Community Size: 1
# Provider Name: 1922319334, Community: 232, Community Size: 1
# Provider Name: 1922360601, Community: 233, Community Size: 1
# Provider Name: 1922419498, Community: 234, Community Size: 1
# Provider Name: 1932382512, Community: 235, Community Size: 1
# Provider Name: 1932631009, Community: 236, Community Size: 1
# Provider Name: 1942209887, Community: 237, Community Size: 1
# Provider Name: 1942230859, Community: 238, Community Size: 1
# Provider Name: 1942230925, Community: 239, Community Size: 1
# Provider Name: 1942480488, Community: 240, Community Size: 1
# Provider Name: 1942681655, Community: 241, Community Size: 1
# Provider Name: 1952793408, Community: 242, Community Size: 1
# Provider Name: 1962420315, Community: 243, Community Size: 1
# Provider Name: 1962494807, Community: 244, Community Size: 1
# Provider Name: 1962729160, Community: 245, Community Size: 1
# Provider Name: 1962780841, Community: 246, Community Size: 1
# Provider Name: 1962931964, Community: 247, Community Size: 1
# Provider Name: 1972565109, Community: 248, Community Size: 1
# Provider Name: 1972766921, Community: 249, Community Size: 1
# Provider Name: 1972861326, Community: 250, Community Size: 1
# Provider Name: 1982683405, Community: 251, Community Size: 1
# Provider Name: 1982696811, Community: 252, Community Size: 1
# Provider Name: 1992118434, Community: 253, Community Size: 1
# Provider Name: 1992299622, Community: 254, Community Size: 1
# Provider Name: 1992811947, Community: 255, Community Size: 1
# Provider Name: 1992969414, Community: 256, Community Size: 1
